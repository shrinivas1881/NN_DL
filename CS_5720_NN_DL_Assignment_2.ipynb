# %% [markdown]
# Use Case Description:
#
# Predicting the diabetes disease
#
# Programming elements:
#
# Keras Basics
#
#
# In class programming:
#
# 1. Use the use case in the class:
#
#    a. Add more Dense layers to the existing code and check how the accuracy changes.

# %% [markdown]
# Existing code

# %%
# Import required Libraries
import pandas
from keras.models import Sequential
from keras.layers.core import Dense, Activation

# load dataset
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

dataset = pd.read_csv("diabetes.csv", header=None).values

X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8],
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 2ms/step - loss: 18.2592 - acc: 0.3455
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 6.0967 - acc: 0.4618
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 2.5640 - acc: 0.6111
# Epoch 4/100
# 18/18 [==============================] - 0s 2ms/step - loss: 2.3329 - acc: 0.6181
# Epoch 5/100
# 18/18 [==============================] - 0s 2ms/step - loss: 2.1607 - acc: 0.6111
# Epoch 6/100
# 18/18 [==============================] - 0s 2ms/step - loss: 2.0312 - acc: 0.6094
# Epoch 7/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.9532 - acc: 0.6007
# Epoch 8/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.8445 - acc: 0.5990
# Epoch 9/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.7534 - acc: 0.5955
# Epoch 10/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.6724 - acc: 0.5920
# Epoch 11/100
# ...

# %% [markdown]
# Adding dense layer to the existing code

# %%
# Import required Libraries
import pandas
from keras.models import Sequential
from keras.layers.core import Dense, Activation

# load dataset
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

dataset = pd.read_csv("diabetes.csv", header=None).values

X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8],
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
More_dense = Sequential() # create model
More_dense.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
## New Dimension added to the existing code
More_dense.add(Dense(15, input_dim=8, activation='relu')) # hidden layer
More_dense.add(Dense(10, input_dim=8, activation='relu')) # hidden layer
More_dense.add(Dense(1, activation='sigmoid')) # output layer
More_dense.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
More_dense_fitted = More_dense.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
print(More_dense.summary())
print(More_dense.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 2ms/step - loss: 2.6615 - acc: 0.5625
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.6691 - acc: 0.4583
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.3095 - acc: 0.5122
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0572 - acc: 0.5382
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9506 - acc: 0.5503
# Epoch 6/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9499 - acc: 0.5747
# Epoch 7/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8684 - acc: 0.6007
# Epoch 8/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.8162 - acc: 0.6181
# Epoch 9/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7114 - acc: 0.6267
# Epoch 10/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7017 - acc: 0.6372
# Epoch 11/100
# ...

# %% [markdown]
# 2. Change the data source to Breast Cancer dataset * available in the source code folder and make required
# changes. Report accuracy of the model.

# %%
# Import required Libraries
import pandas
from keras.models import Sequential
from keras.layers.core import Dense, Activation

from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# load dataset
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

dataset = pd.read_csv("breastcancer.csv", skiprows=0,usecols=range(1,32))

X=dataset.iloc[:,1:].values
y=dataset.iloc[:,0].values

# Encoding the Target variable
label_encoder = le.fit(y)
Y = label_encoder.transform(y)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y,
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=30, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 3ms/step - loss: 17.7728 - acc: 0.4413
# Epoch 2/100
# 14/14 [==============================] - 0s 2ms/step - loss: 8.7404 - acc: 0.3075
# Epoch 3/100
# 14/14 [==============================] - 0s 5ms/step - loss: 3.9791 - acc: 0.2300
# Epoch 4/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5971 - acc: 0.4836
# Epoch 5/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5466 - acc: 0.7277
# Epoch 6/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3423 - acc: 0.9155
# Epoch 7/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2707 - acc: 0.9202
# Epoch 8/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2610 - acc: 0.9225
# Epoch 9/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2608 - acc: 0.9155
# Epoch 10/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2486 - acc: 0.9225
# Epoch 11/100
# ...

# %% [markdown]
# 3. Normalize the data before feeding the data to the model and check how the normalization change your
# accuracy (code given below).
#
# from sklearn.preprocessing import StandardScaler
#
# sc = StandardScaler()

# %%
# Import required Libraries
import pandas
from keras.models import Sequential
from keras.layers.core import Dense, Activation

from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# load dataset
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

dataset = pd.read_csv("breastcancer.csv", skiprows=0,usecols=range(1,32))

x=dataset.iloc[:,1:].values

# Normalizing the data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

X=sc.fit_transform(x)

y=dataset.iloc[:,0].values

# Encoding the Target variable
label_encoder = le.fit(y)
Y = label_encoder.transform(y)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y,
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=30, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 3ms/step - loss: 0.7663 - acc: 0.4789
# Epoch 2/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5746 - acc: 0.6854
# Epoch 3/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4575 - acc: 0.7864
# Epoch 4/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3794 - acc: 0.8615
# Epoch 5/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3227 - acc: 0.8967
# Epoch 6/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2811 - acc: 0.9178
# Epoch 7/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2483 - acc: 0.9319
# Epoch 8/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2224 - acc: 0.9413
# Epoch 9/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2009 - acc: 0.9460
# Epoch 10/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1831 - acc: 0.9460
# Epoch 11/100
# ...

# %% [markdown]
# In class programming:
#
# Use Image Classification on the hand written digits data set (mnist)
#
# 1. Plot the loss and accuracy for both training data and validation data using the history object in the source
# code

# %%
# Import required Libraries
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical

(train_images,train_labels),(test_images, test_labels) = mnist.load_data()

print(train_images.shape[1:])
#process the data
#1. convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature
dimData = np.prod(train_images.shape[1:])
print(dimData)
train_data = train_images.reshape(train_images.shape[0],dimData)
test_data = test_images.reshape(test_images.shape[0],dimData)

#convert data to float and scale values between 0 and 1
train_data = train_data.astype('float')
test_data = test_data.astype('float')
#scale data
train_data /=255.0
test_data /=255.0
#change the labels frominteger to one-hot encoding. to_categorical is doing the same thing as LabelEncoder()
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

#creating network
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                   validation_data=(test_data, test_labels_one_hot))
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step
# (28, 28)
# 784
# Epoch 1/10
# 235/235 [==============================] - 9s 37ms/step - loss: 0.2937 - accuracy: 0.9114 - val_loss: 0.1488 - val_accuracy: 0.9505
# Epoch 2/10
# 235/235 [==============================] - 7s 32ms/step - loss: 0.1017 - accuracy: 0.9686 - val_loss: 0.0804 - val_accuracy: 0.9731
# Epoch 3/10
# 235/235 [==============================] - 6s 27ms/step - loss: 0.0631 - accuracy: 0.9804 - val_loss: 0.0813 - val_accuracy: 0.9731
# Epoch 4/10
# 235/235 [==============================] - 8s 36ms/step - loss: 0.0452 - accuracy: 0.9854 - val_loss: 0.0709 - val_accuracy: 0.9790
# Epoch 5/10
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0319 - accuracy: 0.9895 - val_loss: 0.0672 - val_accuracy: 0.9798
# Epoch 6/10
# 235/235 [==============================] - 8s 32ms/step - loss: 0.0229 - accuracy: 0.9930 - val_loss: 0.0657 - val_accuracy: 0.9810
# Epoch 7/10
# ...

# %%
# Import required Libraries
import matplotlib.pyplot as plt

# Assuming you have the `history` object containing loss and accuracy values

# Plotting loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plotting accuracy
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# 2. Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model
# on that single image.

# %%
# Select an image from the test data
image_index = 0  # Change this index to select a different image
selected_image = test_data[image_index].reshape(28, 28)  # Reshape the image to its original dimensions

# Plot the selected image
plt.imshow(selected_image, cmap='gray')
plt.title('Selected Image')
plt.axis('off')
plt.show()

# Perform inference on the selected image
prediction = model.predict(np.array([test_data[image_index]]))
predicted_label = np.argmax(prediction)

print("Predicted Label:", predicted_label)
# Out:
# 1/1 [==============================] - 0s 313ms/step
# Predicted Label: 7

# %% [markdown]
# 3. We had used 2 hidden layers and Relu activation. Try to change the number of hidden layer and the
# activation to tanh or sigmoid and see what happens.

# %%
# creating network with 3 hidden layers and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(dimData,)))
model.add(Dense(256, activation='tanh'))
model.add(Dense(128, activation='tanh'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                   validation_data=(test_data, test_labels_one_hot))
# Out:
# Epoch 1/10
# 235/235 [==============================] - 6s 24ms/step - loss: 0.3374 - accuracy: 0.8967 - val_loss: 0.2546 - val_accuracy: 0.9176
# Epoch 2/10
# 235/235 [==============================] - 7s 30ms/step - loss: 0.1495 - accuracy: 0.9558 - val_loss: 0.1751 - val_accuracy: 0.9432
# Epoch 3/10
# 235/235 [==============================] - 6s 25ms/step - loss: 0.0988 - accuracy: 0.9698 - val_loss: 0.1403 - val_accuracy: 0.9522
# Epoch 4/10
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0707 - accuracy: 0.9786 - val_loss: 0.0824 - val_accuracy: 0.9740
# Epoch 5/10
# 235/235 [==============================] - 6s 24ms/step - loss: 0.0523 - accuracy: 0.9841 - val_loss: 0.0840 - val_accuracy: 0.9727
# Epoch 6/10
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0396 - accuracy: 0.9873 - val_loss: 0.0763 - val_accuracy: 0.9766
# Epoch 7/10
# ...

# %% [markdown]
# 4. Run the same code without scaling the images and check the performance?

# %%
# Import required Libraries
import numpy as np
from keras.datasets import mnist
from keras.layers import Dense
from keras.models import Sequential
from keras.utils import to_categorical

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Reshape the images
dimData = np.prod(train_images.shape[1:])
train_data = train_images.reshape(train_images.shape[0], dimData)
test_data = test_images.reshape(test_images.shape[0], dimData)

# Convert data to float (without scaling)
train_data = train_data.astype('float32')
test_data = test_data.astype('float32')

# Change the labels from integer to one-hot encoding
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

# Creating the network
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# Fit the model
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                    validation_data=(test_data, test_labels_one_hot))
# Out:
# Epoch 1/10
# 235/235 [==============================] - 9s 34ms/step - loss: 6.7334 - accuracy: 0.8764 - val_loss: 0.7311 - val_accuracy: 0.9208
# Epoch 2/10
# 235/235 [==============================] - 7s 29ms/step - loss: 0.4183 - accuracy: 0.9461 - val_loss: 0.4076 - val_accuracy: 0.9390
# Epoch 3/10
# 235/235 [==============================] - 7s 30ms/step - loss: 0.2335 - accuracy: 0.9596 - val_loss: 0.2895 - val_accuracy: 0.9571
# Epoch 4/10
# 235/235 [==============================] - 9s 36ms/step - loss: 0.1846 - accuracy: 0.9679 - val_loss: 0.2635 - val_accuracy: 0.9604
# Epoch 5/10
# 235/235 [==============================] - 7s 29ms/step - loss: 0.1614 - accuracy: 0.9725 - val_loss: 0.3956 - val_accuracy: 0.9548
# Epoch 6/10
# 235/235 [==============================] - 7s 31ms/step - loss: 0.1326 - accuracy: 0.9767 - val_loss: 0.3185 - val_accuracy: 0.9607
# Epoch 7/10
# ...
